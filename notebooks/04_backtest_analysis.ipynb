# %% [markdown]
# # HelionRiskWorld — Backtest Analysis
#
# > Research notebook. No notebook-only logic — import from `helion_risk_world` (SPEC.md §25).
#
# Decompose gross vs net PnL, regime-wise performance, no-trade quality, risk-shield interventions from FinalDecision audit records. See docs/backtesting_plan.md.

# %%
import sys
sys.path.insert(0, '../src')
import helion_risk_world as hrw
print('HRW', hrw.__version__)
