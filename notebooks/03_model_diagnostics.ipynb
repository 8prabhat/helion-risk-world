# %% [markdown]
# # HelionRiskWorld — Model Diagnostics
#
# > Research notebook. No notebook-only logic — import from `helion_risk_world` (SPEC.md §25).
#
# Inspect head distributions, quantile coverage, calibration (ECE), rollout error, OOD scores. See SPEC.md §22, §26.

# %%
import sys
sys.path.insert(0, '../src')
import helion_risk_world as hrw
print('HRW', hrw.__version__)
