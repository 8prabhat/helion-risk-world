# %% [markdown]
# # HelionRiskWorld — Feature Validation
#
# > Research notebook. No notebook-only logic — import from `helion_risk_world` (SPEC.md §25).
#
# Validate the SHARED FeatureBuilder output: ATM-relative surface alignment, no portfolio fields among market features (run `assert_no_portfolio_in_market`). See docs/feature_engineering.md.

# %%
import sys
sys.path.insert(0, '../src')
import helion_risk_world as hrw
print('HRW', hrw.__version__)
