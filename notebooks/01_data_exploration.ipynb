# %% [markdown]
# # HelionRiskWorld — Data Exploration
#
# > Research notebook. No notebook-only logic — import from `helion_risk_world` (SPEC.md §25).
#
# Explore OHLCV/OI/futures/option-chain/VIX coverage and point-in-time availability. Verify `available_at <= ts` everywhere. See docs/data_sources.md.

# %%
import sys
sys.path.insert(0, '../src')
import helion_risk_world as hrw
print('HRW', hrw.__version__)
